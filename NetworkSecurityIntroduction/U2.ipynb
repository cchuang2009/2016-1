# %%
from IPython.display import YouTubeVideo

# %%
# Wintalkers

YouTubeVideo('KOmH0_F8_XI')

# %%
# U571 
YouTubeVideo('2imOf6-H3tI')

# %%
# Game in Simulation
YouTubeVideo('5DcOR6r31X0')

# %%
# A Beautiful mind 
YouTubeVideo('aS_d0Ayjw4o')

# %%
# Srinivasa Ramanujan
YouTubeVideo('oXGm9Vlfx4w')

# %%
# The Net
YouTubeVideo('46qKHq7REI4')

# %%
# The Secret Life of Walter Mitty
YouTubeVideo('bZRADz6DNog')

# %%
# 聽風者 The Silent War
YouTubeVideo('45PHsCdFYhg')

# %%
# Mr. Robot
YouTubeVideo('xIBiJ_SzJTA')

# %%
# A-Team 42:27
YouTubeVideo('2eDMF3sLNs8')

# %%
# Chris de Burgh, Patricia the Stripper
YouTubeVideo('tg4lGCm2C3o')

# %%
# Cat Stevens, Wild World
YouTubeVideo('WkZJSFd0Ghw')
