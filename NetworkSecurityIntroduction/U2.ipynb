# %%
from IPython.display import YouTubeVideo

# %%
# U571 
YouTubeVideo('2imOf6-H3tI')

# %%
# Game in Simulation
YouTubeVideo('5DcOR6r31X0')

# %%
# The Net
YouTubeVideo('46qKHq7REI4')

# %%
# A Beautiful mind 
YouTubeVideo('aS_d0Ayjw4o')

# %%
# Srinivasa Ramanujan
YouTubeVideo('oXGm9Vlfx4w')

# %%
# The Secret Life of Walter Mitty
YouTubeVideo('bZRADz6DNog')
