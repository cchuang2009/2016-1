# %% [markdown]
# # Machine Learning ShortCut

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2.4em;font-face:bold">
# Packages
# ===
# </code>

# %% [markdown]
# <code style="background-color:blue;color:white;font-size:1.6em;font-face:bold">
# sklearn, API
# ---
# </code>

# %% [markdown]
# ### Scikit-learn package
# The scikit-learn package is built of many sub-packages that each cover a different part of machine learning. You will almost always interact with scikit-learn by importing a specific class or function in the following manner.
#
# ### Template of using sklearn
#
# ```
# # load data, 載入資料
# import pandas as pd
# df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data', names = column_names )
#
# ...
# # Remove missing values
# # Binarize columns with string values with pd.get_dummies
# ...
#
# # divide data into train and test groups, with 75%, 25% randomly, 將資料分成訓練, 測試兩組
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(df[column_names[1:10]], data[column_names[10]], \
#                                                        test_size=0.25, random_state=33)
#
# # Normalize the data, 正規化資料
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import LogisticRegression
# ss = StandardScaler()
# X_train = ss.fit_transform(X_train)
# X_test = ss.transform(X_test)
#
# # training model, 建立模型
# lrc = LogisticRegression()
#
# # fit and make predict data, 模型訓練和使用結果
# lrc.fit(X_train, y_train)
# lrc_y_predict = lrc.predict(X_test)
#
# # Validate and score Model, 評分
# from sklearn.metrics import classification_report
# lrc.score(X_test, y_test)
# ```

# %% [markdown]
# Details
# ---
#
#
# > `from sklearn.sub_package import SomeEstimator`
#
# Or like this:
#
# > `from sklearn.sub_package import some_function`
#
# It's a good idea to [look through the API right now](http://scikit-learn.org/stable/modules/classes.html) to see all the available functionality scikit-learn has to offer.
#
# ### Best of API
#
# There are lots of sub-packages and a tremendous amount of classes and functions available for you to import into your project. The below classes and functions are, from my experience, the most commonly used ones. Make sure to explore the API in-depth to become aware of all things you can do.
#
# #### Datasets
# Scikit-learn has many datasets that come packaged with it for quick exploration. 使用 sklearn 的資料
# + **`sklearn.datasets`** - `load_digits, load_boston, load_iris`
#
# #### Dummy Estimators
# Use this as the default model for starting out.
# + **`sklearn.dummy`** - `DummyClassifier, DummyRegressor`
#
# #### Preprocessing
# These use the **`transform`** or **`fit_transform`** methods
# + **`sklearn.preprocessing`** - `StandardScaler, PolynomialFeatures`
#
# #### Model Selection, 模型選擇
# + **`sklearn.model_selection`** - `KFOLD, test_train_spit, cross_val_score`
#
# #### Neighbors, 鄰旁
# + **`sklearn.neighbors`** - `KNeighborsClassifier, KNeighborsRegressor`
#
# #### Discriminant analysis
# + **`sklearn.discriminant_analysis`** - `LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis`
#
# #### NaiveBayes, 貝斯模型
# + **`sklearn.naive_bayes`** - `MultinomialNB`
#
# #### Linear Models, 線性模型
# + **`sklearn.linear_model`** - `LinearRegression, LogisticRegression, Lasso, Ridge, ElasticNet`
#
# #### Decision Trees, 決策樹
# + **`sklearn.tree`** - `DecisionTreeClassifier, DecisionTreeRegressor`
#
# #### Support vector machines, 向量機
# + **`sklearn.svm`** - `SVR, SVC`
#
# #### Neural Networks, 神經網絡
# + **`sklearn.neural_network`** - `MLPClassifier, MLPRegressor`
#
# #### Ensemble, 集成
# Mainly tree-based ensembling.
# + **`sklearn.ensemble`** - `RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor`
#
# #### Unsupervised Learning, 非監督學習
# + **`sklearn.cluster`** - `KMeans`
#
# #### Matrix decomposition
# These use the **`transform`** or **`fit_transform`** methods.
# + **`sklearn.decomposition`** - `PCA, NMF, LatentDirichletAllocation`
#
# #### Text Extraction
# These use the **`transform`** or **`fit_transform`** methods.
# + **`feature_extraction.text`** - `CountVectorizer, TfidfVectorizer`
#
#
# #### Metrics
# + **`sklearn.metrics`** - `f1_score, roc_auc_score, roc_curve`
#
# #### Pipeline
# + **`sklearn.pipeline`** - `Pipeline`
#
# ### Regressor vs Classifier
# Notice that most of the supervised machine learning methods have one class each for regression and classification.
#
# ### Sklearn gotchas
# + By convention put your input array into a variable named **`X`** and target array into variable **`y`**.
# + Convert both input and output to numpy arrays before using scikit-learn
# + Your input array must be two-dimensional, even if there is only one predictor variable
# + Although, you can have multiple labels for your **`y`** for each observation, this is very rare. When you have a single label for each observation, convert your **`y`** into a one dimensional numpy array.
# + **`X`** and **`y`** must not contain any missing values
# + **`X`** must be all numeric.
# + **`y`** can be an array of strings or numbers
#
# ### Typical workflow from pandas to prediction
# Here is an outline of a very basic workflow for going from initial data pull to machine learning
# > `read data in pandas dataframe`
# > `lots of pandas manipulations`
# > `Do lots of EDA`
#
# > `Still in pandas, prepare for machine learning`
# > `Remove missing values`
# > `Binarize columns with string values with pd.get_dummies`
#
# > `move to sklearn by converting pandas objects to numpy arrays X and y`
# > `Scale continuous features`
# > `Other transformation to either features or target variables - take log, etc...`
#
# > `Split data - kfold, or validation set`
# > `Import estimator from sklearn`
# > `Instantiate estimator`
# > `Use fit method`
# > `Use predict or score method to validate model`

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2.4em;font-face:bold">
# Regression: Predict Continuous Data
# ===
# </code>
# Predict how a dependent variable (output, $t$) changes when any of the independent variables (inputs, or features, $x$) change,
# for example, how house prices change as a function of neighborhood and size, or how time spent on a web page varies as a function of the number of ads and content
# type. Training data has $N$ samples and $D$ features.
#
# 1. Linear Regression
#   - Linear Model (with numeric outputs), Logistic Regression (output in  0 or 1):<img src="ML/Reg-1.png" width=70%></img>
#
#   - <img src="ML/Reg-2.png" width=70%></img>
#   - <img src="ML/Reg-3.png" width=70%></img>
#   <big>**Comparion between L1 and L2:**</big>
#   <img src="ML/Reg-4.png" width=70%></img>
# 2. Nonlinear:
#   - How it works: “Reword” a nonlinear model in linear terms using nonlinear basis functions, $\phi_j(x)$, so we can use linear model machinery to solve nonlinear problems. Linear model becomes:
#     $$y=w_0\phi_0(x)+\cdots+w_n\phi_n(x)$$
#     <img src="ML/Nreg-1.png" width=70%></img>
#   - <img src="ML/Nreg-2.png" width=80%></img>
#   - <img src="ML/Nreg-3.png" width=80%></img>
#   - <img src="ML/Nreg-4.png" width=80%></img>

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2.4em;font-face:bold">
# Classification: Predict Categorical Data
# ===
# </code>
# Predict the class, or label $(t)$, of a sample based on its features $(x)$. Examples: Recognize hand-written digits, or mark email as spam. In scikit-learn, labels are represented as integers and get expanded internally into matrices of binary choices between unique integer labels. Use class_weight='balanced' in most models to adjust for unbalanced datasets (more training data from one class than others). Training data has $N$ samples and $D$ features.
#
#   -  Logistic Regression: X, input, Y, output in value 0 or 1. $p,\color{red}{1-p}={\cal P}(Y=1|X),\color{red}{{\cal P}(Y=0|X)}$, and
#
#      \begin{eqnarray}
#         \ln\left(\frac{p}{1-p}\right)&=&w_0+w_1x_1+w_nx_n+\epsilon &(=g(x_i))\\
#         p&=& \frac{1}{1+e^{g(x_i)}}
#      \end{eqnarray}
#      which maps data from $\mathbb R$ to $(0,1)$. <img src="ML/C1.png" width=70%></img>
#   - <img src="ML/C2.png" width=70%></img>
#   - <img src="ML/C3.png" width=70%></img>
#   - <img src="ML/C4.png" width=70%></img>
#   - <img src="ML/C5.png" width=80%></img>
#   - <img src="ML/C6.png" width=80%></img>
#   - <img src="ML/C7.png" width=80%></img>

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2.4em;font-face:bold">
# Clustering: Unsupervised Learning
# ===
# </code>
# Predict the underlying structure in features, without the use of targets or labels. Splits samples into groups called “clusters”. With no targets, models are trained by minimizing some definition of “distance” within a cluster. Data has $N$ samples,
# $D$ features, and the model discovers $k$ clusters. Models can be used for prediction or for transformation, by reducing $D$ features into one with $k$ unique values.
#
#   - <img src="ML/Cluster-1.png" width=70%></img>
#   - <img src="ML/Cluster-2.png" width=70%></img>
#   - <img src="ML/Cluster-3.png" width=70%></img>
#   - <img src="ML/Cluster-4.png" width=70%></img>
#   - <img src="ML/Cluster-5.png" width=80%></img>
#   - <img src="ML/Cluster-6.png" width=80%></img>
#   - <img src="ML/Cluster-7.png" width=80%></img>
#   - <img src="ML/Cluster-8.png" width=80%></img>

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Data Create, Data Manipuling
# ---
# </code>
# - **Create dataframe**,
# ```
# data={'年份': [2002,2006,2010,2014],
#       '主辦國':['韓國/日本','德國','南非','巴西'],
#       '衛冕冠軍':['法國','巴西','意大利','西班牙'],
#       '最後成績':['分組賽出局','八強出局','分組賽出局','分組賽出局'],
#       '當屆冠軍': ['巴西','意大利','西班牙','德國']
# }
# idx=[2002,2006,2010,2014]
# df = pd.DataFrame(data, index =idx)
# ```

# %%
import pandas as pd

# %%
data={'年份': [2002,2006,2010,2014],
      '主辦國':['韓國/日本','德國','南非','巴西'],
      '衛冕冠軍':['法國','巴西','意大利','西班牙'],
      '最後成績':['分組賽出局','八強出局','分組賽出局','分組賽出局'],
      '當屆冠軍': ['巴西','意大利','西班牙','德國']  
}
idx=range(1,5)
df = pd.DataFrame(data, index =idx)
df
# Out:
#      主辦國    年份   最後成績 當屆冠軍 衛冕冠軍
# 1  韓國/日本  2002  分組賽出局   巴西   法國
# 2     德國  2006   八強出局  意大利   巴西
# 3     南非  2010  分組賽出局  西班牙  意大利
# 4     巴西  2014  分組賽出局   德國  西班牙

# %% [markdown]
# - **Drop an observation (row)**
# ```
# df.drop([1])
# ```

# %%
df1=df.drop([1])

# %%
df1
# Out:
#   主辦國    年份   最後成績 當屆冠軍 衛冕冠軍
# 2  德國  2006   八強出局  意大利   巴西
# 3  南非  2010  分組賽出局  西班牙  意大利
# 4  巴西  2014  分組賽出局   德國  西班牙

# %% [markdown]
# - **Drop a variable (column)**, Note: axis=1 denotes that we are referring to a column, not a row
#
# ```
# df.drop('reports', axis=1)
# ```

# %%
df.drop('衛冕冠軍', axis=1)
# Out:
#      主辦國    年份   最後成績 當屆冠軍
# 1  韓國/日本  2002  分組賽出局   巴西
# 2     德國  2006   八強出局  意大利
# 3     南非  2010  分組賽出局  西班牙
# 4     巴西  2014  分組賽出局   德國

# %% [markdown]
# - **Drop a row if it contains a certain value **, (in this case, '分組賽出局')
#
# ```
# df[df['最後成績'] != '分組賽出局']
# ```

# %%
df[df['最後成績'] == '分組賽出局']
# Out:
#      主辦國    年份   最後成績 當屆冠軍 衛冕冠軍
# 1  韓國/日本  2002  分組賽出局   巴西   法國
# 3     南非  2010  分組賽出局  西班牙  意大利
# 4     巴西  2014  分組賽出局   德國  西班牙

# %%
df.to_csv("fifa.csv")

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Setup
# ---
# </code>
#
# ```
# # import packages
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # display the picture inline
# %matplotlib inline
#
# # display zoomable picture
# %matplotlib notebook
# ```

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm
# from KaggleAux import predict as ka # see github.com/agconti/kaggleaux for more details

# %matplotlib inline
# Out:
# /Users/cch/anaconda36/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv("data/train.csv")

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Plotting
# ---
# </code>
# - **Series**,  with a series, pandas plots the values against the index:
# ```
#  > ax=s.plot()
# ```
# <img src="imgs/series.png" width=50% />
# - **Dataframe**, with a Dataframe, pandas create one line per column:
# ```
#  > ax=df.plot()
# ```
# <img src="imgs/dataframe.png" width=50% />
# - **Labels**, Use Matplotlib to override or add annotations:
#
# ```
#  > ax.set_xlabel('Time')
#  > ax.set_ylabel('Value')
#  > ax.set_title('Experiment A')
# ```
#    pass labels if yoy want to override the column names and set the legend location:
# ```
#  > ax.legend(labels,loc="best")
# ```
# <img src="imgs/labels.png" width=50% />

# %%
df.Age[df.Pclass == 1].plot(kind='kde')    
df.Age[df.Pclass == 2].plot(kind='kde')
df.Age[df.Pclass == 3].plot(kind='kde')
 # plots an axis lable
plt.xlabel("Age")    
plt.title("Age Distribution within classes")
# sets our legend for our graph.
plt.legend(('1st Class', '2nd Class','3rd Class'),loc='best')

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Plotting with Auguments
# ---
# </code>
#
# <img src="imgs/augument.png" width=50% />
#
#
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Kinds of Plotting
# ---
# </code>
# <img src="imgs/kind.png" width=80% />

# %%
plt.figure(figsize=(12,8))
ax=plt.subplot(3,1,1)
df.Age[df.Pclass == 1].plot()
ax=plt.subplot(3,1,2)
df.Age[df.Pclass == 2].plot()
ax=plt.subplot(3,1,3)
df.Age[df.Pclass == 3].plot()

# %%
df1 = df[np.isfinite(df['Age'])]

# %%
#df1=df.Age.dropna()
plt.figure(figsize=(12,8))
ax=plt.subplot(3,1,1)
df1.Age[df1.Pclass == 1].plot()
ax=plt.subplot(3,1,2)
df1.Age[df1.Pclass == 2].plot()
ax=plt.subplot(3,1,3)
df1.Age[df1.Pclass == 3].plot()

# %% [markdown]
# Still no Good and not satisfied, let us introduce, "seanborn", the professional statistical visualisation package; install it by pip:
# ```
# pip install seaborn
# ```

# %%
import seaborn as sns
sns.set()

# %%
sns.countplot("Pclass" ,data=df)

# %%
#more specific
sns.countplot("Pclass", data=df, hue="Sex")

# %%
#The relationship between "Pclass" and "Survived".
sns.factorplot("Pclass","Survived",data=df,order=[1,2,3],aspect=2)

# %%
sns.factorplot("Pclass","Survived", hue="Sex", data= df, order=[1,2,3], aspect=2)

# %%
sns.distplot(df.Age.dropna());
# Out:
# /Users/cch/anaconda36/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
g = sns.FacetGrid(df, row='Survived', col='Sex')
g.map(sns.distplot, "Age")
# Out:
# /Users/cch/anaconda36/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Data Reading/writting
# ---
# </code>
# Methods to read data are all named `pd.read_*` where `*` is the file type. Series and DataFrames can be saved to disk using their `to_*` method.
#
#
#
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Usage Patterns
# </code>
#  - Use `pd.read_clipboard()` for one-off data extractions.
#  - Use the other `pd.read_*` methods in scripts for repeatable analyses.
#
#
#
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Reading text into Dataframe
# </code>
# <img src="imgs/data.png" width=80% />
#
# **Other arguments**
#
# - names: set or override column names
# - parse_dates: accepts multiple argument types, see on the right • converters: manually process each element in a column
# - comment: character indicating commented line
# - chunksize: read only a certain number of rows each time
#
# **Possible values of parse_dates **
#
# - [0, 2]: Parse columns 0 and 2 as separate dates
# - [[0, 2]]: Group columns 0 and 2 and parse as single date
# - {'Date': [0, 2]}: Group columns 0 and 2, parse as
# single date in a column named Date.
#
# Dates are parsed after the converters have been applied.
#
#
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Parsing Tables from the Web
# </code>
# <img src="imgs/web.png" width=80% />
#
#
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Save data structure
# </code>
#  - to disk
# ```
# > s_df.to_csv(filename)
# > s_df.to_excel(filename)
# ```
#  - to single Excel file
# ```
# > writer = pd.ExcelWriter(filename)
# > df1.to_excel(writer, sheet_name='First')
# > df2.to_excel(writer, sheet_name='Second')
# > writer.save()
# ```
#
#
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# From/To Database
# </code>
#  - Read, using SQLAlchemy. Supports multiple databases:
# ```
# > from sqlalchemy import create_engine
# > engine = create_engine(database_url)
# > conn = engine.connect()
# > df = pd.read_sql(query_str_or_table_name, conn)
# ```
#  - Write:
# ```
# > df.to_sql(table_name, conn)
# ```

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Computation With Series/Dataframes
# ---
# </code>
#  <img src="imgs/rule1.png" width=70% />
# <img src="imgs/rule2.png" width=100% />
# <img src="imgs/rule31.png" width=70% />

# %% [markdown]
# <font size=+1.2>
# **count**: Number of non-null observations<br>
# **sum**: sum of values<br>
# **mean**: Mean of values<br>
# **mad**: Mean absolute Deviation<br>
# **median**: Arithmetric mean of values<br>
# **min**: Minimum<br>
# **max**: Maximum<br>
# **mode**: Mode<br>
# **prod**: Product of values<br>
# **std**: Bessel-corrected sample standard deviation<br>
# **var**: unbiased variance<br>
# **sem**: Standard error of the mean<br>
# **skew**: Sample skewness (3rd moment)<br>
# **kurt**: Sample kurtosis (4th moment)<br>
# **quantile**: Sample quantile (Value at %) values<br>
# **value_counts**: Count of unique values
# </font>

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Dataframe Split/Apply/Combine
# ---
# </code>
# <img src="imgs/split1.png" width=70% />
# <img src="imgs/split2.png" width=70% />
# <img src="imgs/split3.png" width=70% />
# <img src="imgs/apply1.png" width=70% />
# <img src="imgs/apply2.png" width=70% />
# <img src="imgs/apply3.png" width=70% />
# <img src="imgs/apply4.png" width=70% />
# <img src="imgs/others.png" width=70% />

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Manipulating Dates and Times
# ---
# </code>
#  Pandas makes a distinction between timestamps, called Datetime objects, and time spans, called Period objects.
#  <img src="imgs/date1.png" width=70% />
# <img src="imgs/date2.png" width=70% />
# <img src="imgs/date3.png" width=70% />
# <img src="imgs/date4.png" width=70% />
# <img src="imgs/date5.png" width=70% />
# <img src="imgs/date6.png" width=70% />

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Vectorized String Operations
# ---
# </code>
# Pandas implements vectorized string operations named after Python's string methods. Access them through the str attribute of string Series
# <img src="imgs/string1.png" width=70% />
# <img src="imgs/string2.png" width=70% />

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Data Structures: Series/DataFrames
# ---
# </code>
# A Series, s, maps an index to values. It is:
#  - Like an ordered dictionary
#  - A Numpy array with row labels and a name
#
# A DataFrame, df, maps index and column labels to values. It is:
#  - Like a dictionary of Series (columns) sharing the same index
#  - A 2D Numpy array with row and column labels
#
# s_df applies to both Series and DataFrames.
# Assume that manipulations of Pandas object return copies.
# <img src="imgs/structure1.png" width=70% />
# <img src="imgs/structure2.png" width=70% />
# <img src="imgs/structure3.png" width=70% />
# <img src="imgs/structure4.png" width=70% />
# <img src="imgs/structure5.png" width=70% />
# <img src="imgs/structure6.png" width=70% />
# <img src="imgs/structure7.png" width=70% />

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Combining DataFrames
# ---
# </code>
# Tools for combining Series and DataFrames together, with SQL-type joins and concatenation. Use join if merging on indices, otherwise use merge.
#
# Merge on Column Values
# ---
# ```
# > pd.merge(left, right, how='inner', on='id')
# ```
# Ignores index, unless on=None. See value of how below.
# Use on if merging on same column in both DataFrames, otherwise use left_on, right_on.
# <img src="imgs/Mdata.png" width=90% />
#
# Concatenating DataFrames
# ---
# ```
#  > pd.concat(df_list)
# ```
# “Stacks” DataFrames on top of each other.
# Set ignore_index=True, to replace index with RangeIndex. Note: Faster than repeated df.append(other_df).
#
# Join on Index
# ---
# ```
# > df.join(other)
# ```
# Merge DataFrames on index. Set on=keys to join on index of df and on keys of other. Join uses pd.merge under the covers

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Cleaning Data with Missing Values
# ---
# </code>
#
#
# Pandas represents missing values as NaN (Not a Number). It comes from Numpy and is of type float64. Pandas has many methods to find and replace missing values.
#
# **Find Missing Values**
#
# ```
# > s_df.isnull() or > pd.isnull(obj)
# > s_df.notnull() or > pd.notnull(obj)
# ```
#
#
# **Replacing Missing Values**
#
#
# ```
#       s_df.loc[s_df.isnull()] = 0  Use mask to replace NaN
# s_df.interpolate(method='linear')  Interpolate using different methods
#       s_df.fillna(method='ffill')  Fill forward (last valid value)
#       s_df.fillna(method='bfill')  Or backward (next valid value)
#            s_df.dropna(how='any')  Drop rows if any value is NaN
#            s_df.dropna(how='all')  Drop rows if all values are NaN
#    s_df.dropna(how='all', axis=1)  Drop across columns instead of rows
# ```

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Reshaping Dataframes/Pivot Tables
# ---
# </code>
#
#  Tools for reshaping DataFrames from the wide to the long format and back. The long format can be tidy, which means that "each variable is a column, each observation is a row"1. Tidy data is easier to filter, aggregate, transform, sort, and pivot.  Reshaping operations often produce multi-level indices or columns, which can be sliced and indexed.
#
#
#
# **MultiIndex**: A Multi-Level Hierarchical Index
#
# Often created as a result of:
# ```
#   > df.groupby(list_of_columns)
#   > df.set_index(list_of_columns)
# ```
# Contiguous labels are displayed together but apply to each row. The concept is similar to multi-level columns.
#
# A **MultiIndex** allows indexing and slicing one or multiple levels at once. Using the Long example from the right:
# ```
#                         long.loc[1900]  Pivot Tables
#             long.loc[(1900, 'March')]   value2
#       long.xs('March', level='Month')   All March rows
# ```
# Simpler than using boolean indexing, for example:
# ```
# > long[long.Month == 'March']
# ```
#
#
#
# **Long to Wide Format and Back with stack() and unstack()**
#
#
#
# Pivot column level to index, i.e. "stacking the columns" (wide to long):
# ```
#  > df.stack()
# ```
# Pivot index level to columns, "unstack the columns" (long to wide):
# ```
#  > df.unstack()
# ```
# If multiple indices or column levels, use level number or name to stack/unstack:
# ```
#  > df.unstack(0) or > df.unstack('Year')
# ```
# A common use case for unstacking, plotting group data vs index after groupby:
# ```
#  > (df.groupby(['A', 'B])['relevant'].mean()
#       .unstack().plot())
# ```
# <img src="imgs/index.png" width=70% />

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">
# Pivot Tables
# ---
# </code>
#
# ```
# > pd.pivot_table(df,
#                 index=cols, (keys to group by for index)
#                 columns=cols2, (keys to group by for columns)
#                 values=cols3, (columns to aggregate)
#                 aggfunc='mean') (what to do with repeated values)
# ```
# Omitting index, columns, or values will use all remaining columns of df. You can "pivot" a table manually using groupby, stack and unstack.
# <img src="imgs/index.png" width=70% />
#
#
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">df.pivot() vs pd.pivot_table</code>
#
# ```
#          df.pivot()   Does not deal with repeated values in index.
#                       It's a declarative form of stack and unstack.
#    pd.pivot_table()   Use if you have repeated values in index
#                       (specify aggfunc argument)
# ```

# %% [markdown]
# <code style="background-color:darkblue;color:white;font-size:2em;font-face:bold">From Wide to Long with melt</code>
#
# Specify which columns are identifiers (id_vars, values will be repeated for each row) and which are "measured variables" (value_vars, will become values in variable column.
# All remaining columns by default).
# ```
# pd.melt(df, id_vars=id_cols, value_vars=value_columns)
# ```
# <img src="imgs/melt.png" width=50% />
