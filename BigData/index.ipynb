# %% [markdown]
# # Table of Contents
# * [Journey Toward Big Data, <small>Kaggle Challenge</small>](#Journey-Toward-Big-Data,-<small>Kaggle-Challenge</small>)
# 	* [Goals of the Lecture](#Goals-of-the-Lecture)
# 	* [Course Components](#Course-Components)
# 		* [Labs](#Labs)
# 	* [Outline](#Outline)
# 		* [What you would learn here](#What-you-would-learn-here)
# 		* [What you expected](#What-you-expected)
# 		* [Week Schedule](#Week-Schedule)
# 		* [Two-credit Course](#Two-credit-Course)
# 		* [Grading](#Grading)
# 		* [Textbooks and References](#Textbooks-and-References)

# %%
from IPython.core.display import HTML
css_file = 'css/ngcmstyle.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Open+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 1000px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1200px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Open Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:900px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Arvo', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Arvo', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Arvo', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Arvo', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Arvo', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# # Journey Toward Big Data, <small>Kaggle Challenge</small>

# %% [markdown]
# <div align="center">by cch, started since 03/23/2017</div>

# %% [markdown]
# ## Goals of the Lecture

# %% [markdown]
# The amount and complexity of information produced in science, engineering, business, and everyday human activity are increasing at a staggering rate. The goal of this course is to expose you to methods and techniques for analyzing and understanding complex data. Data Science lies at the intersection of statistics, computer science, and, of course, the domain from which the data comes from. This course will provide an introduction to the former two: statistics and computer science and provide you with a toolset to conquer problems in your domain!
#
# -  Introduce the basics of Machine Learning, and some skills useful in practice.<br>
# -  Introduce the core packages of Python Machine Learning, so that we can make use of the rich tool
# set available; for more complicated problems, we would implement necessary schemes to do data analysis.<br>
# - Practice the schemes introduced in lectures over selected data from Kaggle and others,
# attendants are encouraged to compete with others on the public databases in the wild data world.<br>
#
# 受益於現在電腦的普及和網路的普及, 產生大量的資料, 從資料中擷取可用的資訊, 改變的現代生活運作方式, 也 直接影響分析技能的基本需求, 進而改變對事情觀察的角度. 對於大量資料的處理、分析、預測往往需要龐大並且複雜 的理論基礎, 往往造成初學者難以跨越的鴻溝. 這門課的目的, 就是為了要弭平這個鴻溝而設計的.
# 這門課的設計, 主要引入成熟容易開發的自由軟體, 主要包含機器學習的函式庫, 依照特定的實例, 從資料的存取 分類, 如何分析預測結果, 並且熟悉相關技術應用的原理, 徹底了解範例的細節, 為了更接近真實的世界, 我們特地從著 名的 Kaggle 及其他資料庫, 選取公開資料實作課程介紹的方法並加以驗證 o

# %% [markdown]
# ## Course Components

# %% [markdown]
# Lectures are used to introduce basic tools for data manipulation and theoretical concepts.
# Labs are used to teaching coding skills and revisit the concepts introduced in lectures in practical terms. We will typically run coding exercises in the lab. We try to help all lecture attendants to set up one’s personal computing lab on one computer devices which could overcome the limit of learning environment due to software and space.

# %% [markdown]
# ### Lectures

# %% [markdown]
# The class meets once a week for lectures and joint class activities. The class activities are designed to help attendants master the relevant materials, to work on their homework in groups, and to get one started on one’s
# project. The weekly schedule of lectures would be posted on our course web site.

# %% [markdown]
# ### Labs

# %% [markdown]
# Labs are an important aspect of the course, as they are meant to give you the technical skills to successfully complete the homework assignments and projects, complementing the theoretical knowledge taught in lectures. Sections will typically consist of a short presentation and live coding, followed by time to complete some exercises with the help of the instructors. Arranged labs include:
#
# 1. Titanic Machine Learning from Disaster, <br>
#    <span class="girk"><span class="girk"><span class="girk">Goals of lab</span></span></span>: Regression, SVM, random forest, cross-validation.
#    - Data Handling: Importing Data with Pandas, Cleaning Data, Exploring Data through Visualizations with Matplotlib
#    - Data Analysis: Supervised Machine learning Techniques:, Logit Regression Model, Support Vector Machine (SVM), Basic Random Forest, Plotting results
#    - Valuation of the Analysis: K-folds cross validation to valuate results locally, compare results of Kaggle.
# - Factor Analysis of Financial Incomes and Prediction Improvement,<br>
#    <span class="girk">Goals of lab</span>: Methods Introduced: Adaptive Lasso Method and Neural Network Model (NN),
#    - Data Analysis: Classify the key-characteristics which affect the income of Finance mostly; setup the model of data analysis and find out the best choice.
#    - For improve the in-sufficiency of least-square method other step-wise regression models, GM model would be introduced to setup apriori-predict model ;
#    - imporve prediction by the GM model and suitable NN.
# - Dengue outbreak at Tainan 2015, <br>
#    <span class="girk">Goals of lab</span>: methods Introduced: Dickey-Fuller Test, Ljung-Box test, ARIMA model
#    - Data Analysis: test whether time series is stationary; detrained if yes;
#    - Classify whether white-noise free is or not by Ljung-Box test;
#    - in case of white-noise free, find the optimal parameters of ARIMA model and forecast the future.

# %% [markdown]
# ## Outline

# %% [markdown]
# ### What you would learn here

# %% [markdown]
# 1. Math background,
# - Computer skills in Data Analysis,
# - training for being reporter.

# %% [markdown]
# ### What you expected

# %% [markdown]
# ???, let me know!

# %% [markdown]
# ### Week Schedule

# %% [markdown]
# - Week 1. Big Data Introduction, and how it changes world,
# ( Data Science Induction by cases and what the truth behind data)
# - Week 2. System setup, and Data Manipulation
# ( System setup, the basic mathematics and the computing schemes we require)
# - Week 3. Modern Three Kingdoms Tale, Apple Inc., TMSC and Samsung Inc. I. Data retrieve, analysis
# ( From data of stock prices of three companies, learn the skills how to gather the data, clean data to suit
# what we need, Assignment: consider to process recent data as exercise.)
# - Week 4. II. Visualization and Future forecast
# ( Introduction the skills , Interactive, 2D/3D data visualization, and basic data fitting for prediction)
# - Week 5. Kaggle Competition, (Project 1) ( Explore the data from project, Titanic Machine Learning from Disaster, introduce the basic machine )
# - Week 6. GeoData Introduction
# ( Incorporated with Google map to visualize geo-data case study and basic cluster analysis)
# - Week 7. Pandas introduction, Statistical library.
# ( Since data is the core of data science, the powerful package, pandas, is introduced for the latter part
# of lecture. Assignment: select a simple data to exercise the pandas capacities.
# - Week 8. Dengue at Tainan 2015, Data collection and basic statistic. (Project 2I)
# ( Clean data, statistic description, visualization)
# - Week 9. Time series and Trends (Project 2II)
# ( Linear/nonlinear Regression)
# - Week 10. Dimensionality Reduction and Density Estimation (Project 2III)
# ( How PCA method reduces the complicity of data and related method)
# - Week 11. Attack Ratio, Rt, estimation for prediction, (Project 2IV)
# ( a simplest method to monitor the epidemic, with time-series data)
# - Week 12. Term report and Discussion
# - Week 13. Financial Data Introduction (project 3 I)
# ( How to get the financial data, scraper scheme for data)
# - Week 14. Data Fitting, Lasso and Adaptive Lasso Methods (project 3 II) ( Classify the best features from time-series data)
# - Week 15. Grey Box method for Prediction (project 3 III)
# ( Implement Grey box to setup up the prediction model with small samples )
# - Week 16. Neural Network Method for Prediction (project 3 IV)
# ( Training last result to do future prediction. Assignment: test other prediction models with the
# data set)
# - Week 17-18. Free Projects Report
# ( Group report demos)

# %% [markdown]
# ### Two-credit Course

# %% [markdown]
# To learn the data science has to own a) advanced mathematical background, b) good computing skills. Thus the lecture is designed in two-credit course, two for lectures and one for lab practice. To keep the certain progress in learning and limit to the resources we can provide, only 20 enrollees are allowed.

# %% [markdown]
# ### Grading

# %% [markdown]
# - Six assignments; each will have a computational part and written part (60%)
# - An in-class exam (20%)
# - A final project (20%)

# %% [markdown]
# ### Textbooks and References

# %% [markdown]
# To introduce the newest concepts and schemes of Data science in time, we try to avail all the lecture source by ourselves in our repository(6) . However, learning technique on data science is a long road to follow and foreign to most ones who are interested; some valued references(1-5) should do helps to the newbies on the field:
#
#
# 1. <a href="../../2016/PythonDataScienceHandbook-master/index.ipynb">Python Data Science Hndbook, Jake Vanderplas, 2015, O'reilly</a>
# - <a href="../../2016/Python_dataAnalytics_Mining/index.ipynb">Python数据分析与挖掘实战, 張良均 等, 2016, China Machine Press. </a>
# - <a href="../../2016/QuantEcon/QuantInvestment/Python%20Quant%20Book">Investment bt Python, 蔡立瑞, 2017, Electronics Industry Pub.</a>
# - [Python for Data Science For Dummies$^®$, Luca Massaron and John Paul Mueller, 2015 by John Wiley & Sons, Inc.](../../../prepare/DigitalLearning/DummiesBigData)
# - [Building Machine Learning Systems with Python, Luis Pedro Coelho, 2015, Packt Pub.](../../../prepare/DigitalLearning/2 BuildingMachineLearningSystemsWithPython-master/index.ipynb)
# - Lecture website, https://github.com/cchuang2009/2016-1

# %% [markdown]
# Data Processing
# ===
# 1. What we want to explore,
# - Data Collection,
# - Data Exploring,
# - Data Washing, for instance, NaN, Null Value, dimensionality Reduction,
# - Modeling,
# - Evaluation and Prediction.

# %% [markdown]
# Development Platform
# ===
# Computer Language and Libraries
# ---
# [Python &ge;3.x, of course](https://www.python.org/)
#     - Series of the Python changed from 2 to 3 few years ago; to get more consistence and match with techniques development, Python 3 is our preferred choice.
#     - Now the recomendation is just go with Python 3.6.x.
#
# Libraries and Modules
# ---
# + [Numpy](http://www.numpy.org/) and [Scipy](http://www.scipy.org)
#     - Core libraries, which provide high performance numerical library particularly array and matrix oriented, and functions doing math computation;
# + [Matplotlib](https://matplotlib.org/)
#     - the grand daddy of Python Plotting libraries, many other libraries build on it to simplify and or stylize it
# + [plotly](https://plot.ly):  It is rather a web-based toolbox for building visualizations, exposing APIs to some programming languages (Python among them).
# + [ipywidgets](http://ipywidgets.readthedocs.io/en/latest/)
# + [qgrid](https://github.com/quantopian/qgrid) &ge;0.3.3,
# + [Sci-kit Learn](http://scikit-learn.org/stable/)
#     - A collection of libraries for almost all types of machine learning with consitant API's and supporting libraries
#
# + [Pandas](http://pandas.pydata.org/), andas is a Python package designed to do work with “labeled” and “relational” data simple and intuitive. Pandas is a perfect tool for data wrangling. It designed for quick and easy data manipulation, aggregation, and visualization. There are two main data structures in the library:
# “Series” — one-dimensional data, “Data Frames”, two-dimensional data.
#     - Main data manipulation library, mostly using DataFrames (think Excel on steroids)
#     - Many IO capabilities GBQ, S-3, Parquet, SQL, CSV, JSON, And web data (stock prices and financial data)
#     - Built on top of Numpy
# + [TensorFlow](https://www.tensorflow.org/), The key feature of TensorFlow is their multi-layered nodes system that enables quick training of artificial neural networks on large datasets. This powers Google’s voice recognition and object identification from pictures.
#     - Google's open source numerical computing library
#     - on which they have built and released a large number of machine learning components
#     - along with a number of supporting components (I/O, encoding, serving etc)
# + [Keras](https://keras.io/), It is an open-source library for building Neural Networks at a high-level of the interface, and it is written in Python. The general idea of Keras is based on layers, and everything else is built around them. Data is prepared in tensors, the first layer is responsible for input of tensors, the last layer is responsible for output, and the model is built in between.
#     - a simplified interface to many Machine learning libraries, also incorporated into TensorFlow
#     - supports Theano, Cntk, Pytorch (and more on the way)
#     + StatsModels (http://www.statsmodels.org/stable/index.html)(https://patsy.readthedocs.io/en/latest/)
#     - Many statistical techniques and the Patsy statistical language (much like R)
# + [Statsmodels](http://www.statsmodels.org/), statsmodels is a library for Python that enables its users to conduct data exploration via the use of various methods of estimation of statistical models and performing statistical assertions and analysis. Among many useful features are descriptive and result statistics via the use of linear regression models, generalized linear models, discrete choice models, robust linear models, time series analysis models, various estimators.
#
# The library also provides extensive plotting functions that are designed specifically for the use in statistical analysis and tweaked for good performance with big data sets of statistical data.
#
# + [PyMC3](https://pymc-devs.github.io/pymc3/index.html)
#     - Baysian Modeling library (in many ways comparable to Stan but newer)
#
# Install without pain
# ---
# Pain gains from desires
# - [Anaconda](https://www.continuum.io/downloads): All of the above,(150+ libraries), (but except TensorFlow, Keras etc) and much more is auto installed for you using the Anaconda distribution including awesome browser-based GUI, notebook.
#
# Others
# ---
# Anaconda brings the Python computing platform but  there are still plenty of libraries and modules not availed by it. We can install python packages, ```example```, as follows:
# - pip:
# ```
# shell> pip install example
# ```

# %% [markdown]
# - or download the source and compile it manually by
#
# ```shell
# shell> python setup.py install
# ```

# %% [markdown]
# Just it? Yes.

# %%
# %load_ext watermark

# %%
# %watermark -a "diffusion" -u -n -t -z -v -m -p numpy,scipy,matplotlib,plotly,qgrid,sklearn,tpot,\
tensorflow,keras,statsmodels,pandas,pymc3,bs4 -g
# Out:
# diffusion
# last updated: Fri Jul 14 2017 09:29:25 CST
#
# CPython 3.6.1
# IPython 6.1.0
#
# numpy 1.13.1
# scipy 0.19.1
# matplotlib 2.0.2
# plotly 2.0.2
# qgrid n
# sklearn 0.18.2
# tpot 0.8.3
# tensorflow 1.2.0
# keras 2.0.4
# statsmodels 0.8.0
# pandas 0.20.3
# pymc3 3.1
# bs4 4.6.0
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)
# system     : Darwin
# release    : 16.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit
# Git hash   :

# %%
# !ls ~/anaconda36/anaconda/lib/python3.6/site-packages
# Out:
# Automat-0.0.0-py3.6.egg-info
# Babel-2.4.0-py3.6.egg-info
# Bottleneck-1.2.1-py3.6.egg-info
# CommonMark
# CommonMark-0.5.4.dist-info
# ConfigArgParse-0.11.0.dist-info
# ConfigSpace
# ConfigSpace-0.3.6.dist-info
# Crypto
# Cython
# Cython-0.25.2-py3.6.egg-info
# Finance_Python-0.5.4.dist-info
# Fiona-1.7.8.dist-info
# Flask-0.12.2-py3.6.egg-info
# Flask-0.12.2.dist-info
# Flask_Compress-1.4.0.dist-info
# Flask_Cors-3.0.2-py3.6.egg-info
# Flask_SeaSurf-0.2.2.dist-info
# HeapDict-1.0.0-py3.6.egg-info
# IPython
# JSAnimation
# Jinja2-2.9.6-py3.6.egg-info
# Keras-2.0.4.dist-info
# Lasagne-0.1.dist-info
# Mako-1.0.6.dist-info
# Markdown-2.2.0.dist-info
# MarkupSafe-1.0.dist-info
# OleFileIO_PL.py
# OpenGL
# OpenSSL
# PIL
# Pillow-4.1.1-py3.6-macosx-10.7-x86_64.egg
# Pillow-4.2.1.dist-info
# PyDispatcher-2.0.5-py3.6.egg-info
# PyFin
# PyOpenGL-3.1.1a1-py3.6.egg-info
# PyPDF2
# PyPDF2-1.26.0.dist-info
# PyQRCode-1.2.1.dist-info
# PyQt5
# PySAL-1.13.0.dist-info
# PyWavelets-0.5.2-py3.6.egg-info
# PyYAML-3.12-py3.6.egg-info
# Pygments-2.2.0-py3.6.egg-info
# Pygments-2.2.0.dist-info
# Pyqtree-0.24.dist-info
# QtAwesome-0.4.3-py3.6.egg-info
# QtPy-1.2.1-py3.6.egg-info
# README
# README.txt
# SQLAlchemy-1.1.11.dist-info
# Scrapy-1.3.3-py3.6.egg-info
# Shapely-1.5.17.post1.dist-info
# Sphinx-1.6.2-py3.6.egg
# Sphinx.pth
# TPOT-0.8.3-py3.6.egg
# Theano-0.9.0.dist-info
# Twisted-17.5.0-py3.6.egg-info
# Unidecode-0.04.20.dist-info
# Werkzeug-0.12.2-py3.6.egg-info
# Werkzeug-0.12.2.dist-info
# XlsxWriter-0.9.6-py3.6.egg-info
# __pycache__
# _cffi_backend.so
# _geoslib.so
# _glmnet.cpython-36m-darwin.so
# _license.so
# _pytest
# _regex.cpython-36m-darwin.so
# _regex_core.py
# _version.py
# _watchdog_fsevents.cpython-36m-darwin.so
# _yaml.cpython-36m-darwin.so
# aeosa
# aeosa.pth
# agate
# agate-1.6.0.dist-info
# alabaster
# alabaster-0.7.10-py3.6.egg-info
# alembic
# alembic-0.9.3.dist-info
# algopy
# algopy-0.5.5.dist-info
# altair
# altair-1.2.0.dist-info
# anaconda_client-1.6.3-py3.6.egg-info
# anaconda_navigator
# anaconda_navigator-1.5.3-py3.6.egg-info
# anaconda_project
# anaconda_project-0.6.0-py3.6.egg-info
# apiclient
# appdirs-1.4.3.dist-info
# appdirs.py
# appier
# appier-1.10.30.dist-info
# appnope
# appnope-0.1.0-py3.6.egg-info
# apptools
# apptools-4.4.0.dist-info
# arch
# arch-4.1.dist-info
# arff.py
# argh
# argh-0.26.2.dist-info
# argparse-1.4.0.dist-info
# argparse.py
# asn1crypto
# asn1crypto-0.22.0-py3.6.egg-info
# astroid
# astroid-1.5.3.dist-info
# astropy
# astropy-1.3.3-py3.6.egg-info
# attr
# attrs-15.2.0-py3.6.egg-info
# auto_sklearn-0.1.3.dist-info
# autobahn
# autobahn-17.5.1-py3.6.egg-info
# autograd
# autograd-1.1.10.dist-info
# automat
# autosklearn
# babel
# backports
# backports.shutil_get_terminal_size-1.0.0-py3.6.egg-info
# backports.weakref-1.0rc1.dist-info
# basemap-1.0.7-py3.6.egg-info
# beautifulsoup4-4.6.0-py3.6.egg-info
# bin
# binstar_client
# bitarray
# bitarray-0.8.1-py3.6.egg-info
# bkcharts
# bkcharts-0.2-py3.6.egg-info
# blaze
# blaze-0.10.1-py3.6.egg-info
# bleach
# bleach-2.0.0.dist-info
# bokeh
# bokeh-0.12.6-py3.6.egg-info
# boto
# boto-2.47.0-py3.6.egg-info
# bottleneck
# branca
# branca-0.2.0.dist-info
# brothon-0.2.0-py3.6.egg
# bruges-0.2.2-py3.6.egg
# bs4
# bz2file-0.98.dist-info
# bz2file.py
# certifi
# certifi-2017.4.17.dist-info
# cffi
# cffi-1.10.0-py3.6.egg-info
# chardet
# chardet-3.0.4-py3.6.egg-info
# chest
# chest-0.2.3-py3.6.egg-info
# click
# click-6.7-py3.6.egg-info
# click_plugins
# click_plugins-1.0.3.dist-info
# cligj
# cligj-0.4.0.dist-info
# cloudpickle
# cloudpickle-0.2.2-py3.6.egg-info
# clyent
# clyent-1.2.2-py3.6.egg-info
# colorama
# colorama-0.3.9-py3.6.egg-info
# colorlover
# colorlover-0.2.1.dist-info
# conda
# conda-4.3.22-py3.6.egg-info
# conda_env
# configargparse.py
# configobj-5.0.6-py3.6.egg-info
# configobj.py
# constantly
# constantly-15.1.0-py3.6.egg-info
# contextlib2-0.5.5-py3.6.egg-info
# contextlib2.py
# corner
# corner-2.0.1.dist-info
# cryptography
# cryptography-1.8.1-py3.6.egg-info
# cssselect
# cssselect-1.0.1-py3.6.egg-info
# cufflinks
# cufflinks-0.8.2.dist-info
# curl
# cv2
# cv2-1.0.dist-info
# cycler-0.10.0-py3.6.egg-info
# cycler.py
# cymem
# cymem-1.31.2.dist-info
# cython.py
# cytoolz
# cytoolz-0.8.2-py3.6.egg-info
# dash
# dash-0.17.5.dist-info
# dash.ly-0.17.3.dist-info
# dash_core_components
# dash_core_components-0.5.0.dist-info
# dash_html_components
# dash_html_components-0.6.2.dist-info
# dash_renderer
# dash_renderer-0.7.3.dist-info
# dask
# dask-0.15.0-py3.6.egg-info
# datashape
# datashape-0.5.4-py3.6.egg-info
# dateutil
# deap-1.0.2-py3.6.egg
# decorator-4.0.11-py3.6.egg-info
# decorator.py
# descartes
# descartes-1.1.0.dist-info
# dill
# dill-0.2.6-py3.6.egg-info
# docopt-0.6.2.dist-info
# docopt.py
# docutils
# docutils-0.13.1-py3.6.egg-info
# easy-install.pth
# easy_install.py
# editor.py
# edward-1.3.3-py3.6.egg
# emcee
# emcee-2.2.1.dist-info
# en_core_web_sm
# en_core_web_sm-1.2.0-py3.6.egg-info
# entrypoints-0.2.3.dist-info
# entrypoints.py
# enum
# enum34-1.1.6.dist-info
# et_xmlfile
# et_xmlfile-1.0.1-py3.6.egg-info
# etherscan
# examples
# external
# fastcache
# fastcache-1.0.2-py3.6.egg-info
# fbprophet
# fbprophet-0.1.1.dist-info
# filterpy
# filterpy-0.1.5.dist-info
# fiona
# fix_yahoo_finance
# fix_yahoo_finance-0.0.18.dist-info
# flake8-3.3.0-py3.6.egg
# flask
# flask_compress.py
# flask_cors
# flask_seasurf.py
# folium
# folium-0.3.0.dist-info
# ftfy
# ftfy-4.4.3.dist-info
# funcy
# funcy-1.7.3.dist-info
# future
# future-0.16.0.dist-info
# gdbn
# gdbn-0.1.dist-info
# gensim
# gensim-1.0.1.dist-info
# geoip2
# geoip2-2.5.0.dist-info
# geopandas
# geopandas-0.2.1.dist-info
# gevent
# gevent-1.2.2-py3.6.egg-info
# glmnet
# glmnet-2.0.0.dist-info
# glue
# glue_core-0.10.4-py3.6.egg-info
# glue_vispy_viewers
# glue_vispy_viewers-0.7.2-py3.6.egg-info
# glueviz-0.10.4-py3.6.egg-info
# gmplot
# gnumpy-0.2.dist-info
# gnumpy.py
# google
# google_api_python_client-1.6.2.dist-info
# googleapiclient
# greenlet-0.4.12-py3.6.egg-info
# greenlet.cpython-36m-darwin.so
# grs-0.7.0-py3.6.egg
# gtfslib
# gtfslib-1.0.0.dist-info
# gtfsplugins
# h5py
# h5py-2.7.0-py3.6-macosx-10.7-x86_64.egg-info
# heapdict.py
# holoviews
# holoviews-1.8.0-py3.6.egg-info
# html5lib
# html5lib-0.999999999.dist-info
# httplib2
# httplib2-0.10.3.dist-info
# hyperlink
# hyperlink-17.1.1-py3.6.egg-info
# idna
# idna-2.5-py3.6.egg-info
# imageio-2.1.2-py3.6.egg
# imagesize
# imagesize-0.7.1-py3.6.egg-info
# incremental
# incremental-16.10.1-py3.6.egg-info
# ipy_table-1.12.dist-info
# ipy_table.py
# ipykernel
# ipykernel-4.6.1-py3.6.egg-info
# ipykernel_launcher.py
# ipyleaflet
# ipyleaflet-0.3.0.dist-info
# ipython-6.1.0-py3.6.egg-info
# ipython_genutils
# ipython_genutils-0.2.0-py3.6.egg-info
# ipyturtle
# ipyturtle-0.2.0.dist-info
# ipyvolume
# ipyvolume-0.3.2-py3.6.egg-info
# ipywidgets
# isodate
# isodate-0.5.4.dist-info
# isort
# isort-4.2.14-py3.6.egg-info
# itsdangerous-0.24-py3.6.egg-info
# itsdangerous.py
# jdcal-1.3-py3.6.egg-info
# jdcal.py
# jedi
# jedi-0.10.2-py3.6.egg-info
# jieba
# jieba-0.38.dist-info
# jinja2
# joblib
# joblib-0.11.dist-info
# jsonschema
# jsonschema-2.6.0-py3.6.egg-info
# jupyter-1.0.0-py3.6.egg-info
# jupyter.py
# jupyter_client
# jupyter_client-5.1.0-py3.6.egg-info
# jupyter_console
# jupyter_console-5.1.0-py3.6.egg-info
# jupyter_contrib_core
# jupyter_contrib_core-0.3.1-py3.6.egg-info
# jupyter_contrib_nbextensions
# jupyter_contrib_nbextensions-0.2.8-py3.6.egg-info
# jupyter_core
# jupyter_core-4.3.0-py3.6.egg-info
# jupyter_highlight_selected_word
# jupyter_highlight_selected_word-0.0.11-py3.6.egg-info
# jupyter_latex_envs-1.3.8.2-py3.6.egg-info
# jupyter_nbextensions_configurator
# jupyter_nbextensions_configurator-0.2.5-py3.6.egg-info
# jupyterlab
# jupyterlab-0.24.1.dist-info
# jupyterlab_launcher
# jupyterlab_launcher-0.2.9.dist-info
# keras
# lasagne
# latex_envs
# lazy_object_proxy
# lazy_object_proxy-1.3.1.dist-info
# leather
# leather-0.3.3.dist-info
# liac_arff-2.1.0.dist-info
# libfuturize
# libpasteurize
# lightfm
# lightfm-1.12.dist-info
# lime
# lime-0.1.1.21.dist-info
# linecache2
# linecache2-1.0.0.dist-info
# llvmlite
# llvmlite-0.18.0-py3.6.egg-info
# lmfit
# lmfit-0.9.6.dist-info
# locket
# locket-0.2.0-py3.6.egg-info
# lockfile
# lockfile-0.12.2.dist-info
# lxml
# lxml-3.8.0-py3.6.egg-info
# mako
# markdown
# markupsafe
# matplotlib
# matplotlib-2.0.2-py3.6-nspkg.pth
# matplotlib-2.0.2-py3.6.egg-info
# maxminddb
# maxminddb-1.3.0.dist-info
# mistune-0.7.4-py3.6.egg-info
# mistune.cpython-36m-darwin.so
# mkl
# mlpy
# mlpy-3.5.1-py3.6.egg-info
# moviepy-0.2.2.11-py3.6.egg
# mpl_toolkits
# mpld3-0.3-py3.6.egg
# mpmath
# mpmath-0.19-py3.6.egg-info
# multipledispatch
# multipledispatch-0.4.9-py3.6.egg-info
# multiprocess-0.70.5-py3.6-macosx-10.7-x86_64.egg
# multitasking
# multitasking-0.0.4.dist-info
# munch
# munch-2.1.1.dist-info
# murmurhash
# murmurhash-0.26.4.dist-info
# nbconvert
# nbconvert-5.2.1-py3.6.egg-info
# nbconvert-5.2.1.dist-info
# nbformat
# nbformat-4.3.0-py3.6.egg-info
# nbgrader
# nbgrader-0.5.0.dist-info
# nbscan-1.0-py3.6.egg-info
# nbsphinx-0.2.13.dist-info
# nbsphinx.py
# nbtutor
# nbtutor-1.0.4-py3.6.egg-info
# networkx
# networkx-1.11.dist-info
# nibabel
# nibabel-2.1.0.dist-info
# nilearn
# nilearn-0.2.6.dist-info
# nisext
# nltk
# nltk-3.2.4-py3.6.egg-info
# nolearn
# nolearn-0.6.0.dist-info
# nose
# nose-1.3.7-py3.6.egg-info
# notebook
# notebook-5.0.0.dist-info
# npmat.py
# numba
# numba-0.33.0-py3.6-macosx-10.7-x86_64.egg-info
# numbergen
# numdifftools
# numdifftools-0.9.20.dist-info
# numexpr
# numexpr-2.6.2-py3.6-macosx-10.7-x86_64.egg-info
# numpy
# numpy-1.13.1.dist-info
# numpydoc
# numpydoc-0.6.0-py3.6.egg-info
# nxpd
# nxpd-0.2.0.dist-info
# oauth2client
# oauth2client-4.1.1.dist-info
# odo
# odo-0.5.0-py3.6.egg-info
# olefile
# olefile-0.44-py3.6.egg
# olefile-0.44-py3.6.egg-info
# openpyxl
# openpyxl-2.4.7-py3.6.egg-info
# packaging
# packaging-16.8-py3.6.egg-info
# packaging-16.8.dist-info
# pandas
# pandas-0.20.3.dist-info
# pandas_datareader
# pandas_datareader-0.4.0-py3.6.egg-info
# pandas_profiling-1.4.0-py3.6.egg
# pandas_profiling.pth
# pandocfilters-1.4.1-py3.6.egg-info
# pandocfilters.py
# param
# param-1.5.0-py3.6.egg-info
# parsedatetime
# parsedatetime-2.3.dist-info
# parsel
# parsel-1.2.0-py3.6.egg-info
# parsimony
# parsimony-0.4.0.dist-info
# partd
# partd-0.3.8-py3.6.egg-info
# past
# path.py
# pathlib-1.0.1.dist-info
# pathlib.py
# pathlib2-2.2.1-py3.6.egg-info
# pathlib2.py
# pathos-0.2.0-py3.6.egg
# pathtools
# pathtools-0.1.2.dist-info
# patsy
# patsy-0.4.1-py3.6.egg-info
# pdfminer
# pdfminer3k-1.3.1.dist-info
# pep8-1.7.0-py3.6.egg-info
# pep8.py
# pexpect
# pexpect-4.2.1-py3.6.egg-info
# pickleshare-0.7.4-py3.6.egg-info
# pickleshare.py
# pip
# pip-9.0.1-py3.6.egg-info
# pkg_resources
# pkgconfig
# pkgconfig-1.1.0-py3.6.egg-info
# plac-0.9.6.dist-info
# plac.py
# plac_core.py
# plac_ext.py
# plac_tk.py
# plotly
# plotly-2.0.2.dist-info
# ply
# ply-3.10-py3.6.egg-info
# png.py
# pox-0.2.3-py3.6.egg
# ppft-1.6.4.7.1-py3.6.egg
# preshed
# preshed-1.0.0.dist-info
# prompt_toolkit
# prompt_toolkit-1.0.14-py3.6.egg-info
# protobuf-3.3.0-py3.6-nspkg.pth
# protobuf-3.3.0.dist-info
# psutil
# psutil-5.2.2-py3.6.egg-info
# psutil-5.2.2.dist-info
# ptyprocess
# ptyprocess-0.5.1-py3.6.egg-info
# py
# py-1.4.34-py3.6.egg-info
# pyLDAvis
# pyLDAvis-2.1.1.dist-info
# pyOpenSSL-17.0.0-py3.6.egg-info
# py_etherscan_api-0.6.0-py3.6.egg-info
# pyaf
# pyaf-1.0-py3.6.egg-info
# pyasn1
# pyasn1-0.2.3-py3.6.egg-info
# pyasn1-0.2.3.dist-info
# pyasn1_modules
# pyasn1_modules-0.0.9.dist-info
# pycosat-0.6.2-py3.6.egg-info
# pycosat.cpython-36m-darwin.so
# pycountry
# pycountry-17.5.14.dist-info
# pycparser
# pycparser-2.17-py3.6.egg-info
# pycrypto-2.6.1-py3.6.egg-info
# pycurl-7.43.0-py3.6.egg-info
# pycurl.cpython-36m-darwin.so
# pydispatch
# pydot-1.2.3-py3.6.egg
# pyface
# pyface-5.1.0.dist-info
# pyflakes
# pyflakes-1.5.0-py3.6.egg-info
# pyflux
# pyflux-0.4.15.dist-info
# pygeoip
# pygeoip-0.3.2.dist-info
# pygments
# pykalman
# pykalman-0.9.5.dist-info
# pylab.py
# pylearn_parsimony-0.3.1-py3.6.egg
# pylint
# pylint-1.6.4-py3.6.egg-info
# pymc
# pymc-2.3.6-py3.6.egg-info
# pymc3
# pymc3-3.1.dist-info
# pynisher
# pynisher-0.4.2.dist-info
# pypandoc
# pypandoc-1.4.dist-info
# pyparsing-2.1.4-py3.6.egg-info
# pyparsing-2.2.0.dist-info
# pyparsing.py
# pypng-0.0.18.dist-info
# pyproj
# pyproj-1.9.5.1-py3.6.egg-info
# pyqrcode
# pyqtree.py
# pyquery
# pyquery-1.2.17.dist-info
# pysal
# pyshp-1.2.11.dist-info
# pystan
# pystan-2.15.0.1.dist-info
# pytest-3.1.1-py3.6.egg-info
# pytest.py
# python_dateutil-1.5-py3.6.egg
# python_dateutil-2.6.0-py3.6.egg-info
# python_editor-1.0.3.dist-info
# python_slugify-1.2.1.dist-info
# pytimeparse
# pytimeparse-1.1.6.dist-info
# pytz
# pytz-2017.2-py3.6.egg-info
# pytz-2017.2.dist-info
# pywt
# pyximport
# pyzmq-16.0.2-py3.6.egg-info
# qgrid
# qstrader
# qstrader-0.0.1-py3.6.egg-info
# qtawesome
# qtconsole
# qtconsole-4.3.0-py3.6.egg-info
# qtpy
# queuelib
# queuelib-1.4.2-py3.6.egg-info
# recommonmark
# recommonmark-0.4.0.dist-info
# redis
# redis-2.10.5-py3.6.egg-info
# regex-2017.4.5.dist-info
# regex.py
# requests
# requests-2.18.1.dist-info
# requests_file-1.4.2.dist-info
# requests_file.py
# requests_ftp
# requests_ftp-0.3.1.dist-info
# rise
# rise-5.0.0-py3.6.egg-info
# rope
# rope_py3k-0.9.4_1-py3.6.egg-info
# rpy2
# rpy2-2.8.5-py3.6.egg-info
# rsa
# rsa-3.4.2.dist-info
# ruamel_yaml
# scikit_image-0.13.0-py3.6.egg-info
# scikit_learn-0.18.2.dist-info
# scipy
# scipy-0.19.1.dist-info
# scraperwiki
# scraperwiki-0.5.1.dist-info
# scrapy
# seaborn
# seaborn-0.7.1-py3.6.egg-info
# selenium
# selenium-3.3.3.dist-info
# service_identity
# service_identity-16.0.0-py3.6.egg-info
# setupegg.py
# setuptools
# setuptools-27.2.0-py3.6.egg
# setuptools-36.0.1.dist-info
# setuptools.pth
# shapefile.py
# shapely
# simplegeneric-0.8.1-py3.6.egg-info
# simplegeneric.py
# simplejson
# simplejson-3.10.0.dist-info
# singledispatch-3.4.0.3-py3.6.egg-info
# singledispatch.py
# singledispatch_helpers.py
# sip.pyi
# sip.so
# sipconfig.py
# sipdistutils.py
# six-1.10.0-py3.6.egg-info
# six-1.10.0.dist-info
# six.py
# skflow
# skflow-0.1.0-py3.6.egg-info
# skggm-0.2.6-py3.6-macosx-10.7-x86_64.egg
# skimage
# sklearn
# sklearn-0.0.dist-info
# slugify
# smart_open
# smart_open-1.5.1.dist-info
# snowballstemmer
# snowballstemmer-1.2.1-py3.6.egg-info
# sockjs
# sockjs_tornado-1.0.3-py3.6.egg-info
# sonnet
# sonnet-0.1.6.dist-info
# spacy
# spacy-1.8.2.dist-info
# sphinxcontrib
# sphinxcontrib_websupport-1.0.1-py3.6.egg-info
# spyder
# spyder-3.1.2-py3.6.egg-info
# spyder_breakpoints
# spyder_io_dcm
# spyder_io_hdf5
# spyder_profiler
# spyder_pylint
# sqlalchemy
# statsmodels
# statsmodels-0.8.0-py3.6.egg-info
# steganography
# steganography-0.1.1.dist-info
# stepic-bzr.dist-info
# stepic.py
# stepic.py.bak
# sympy
# sympy-1.1-py3.6.egg-info
# sympy-1.1.dist-info
# tables
# tables-3.3.0-py3.6.egg-info
# tabulate-0.7.5-py3.6.egg
# tensorflow
# tensorflow-1.2.0.dist-info
# termcolor-1.1.0.dist-info
# termcolor.py
# terminado
# terminado-0.6-py3.6.egg-info
# test
# test_path.py
# test_pycosat.py
# test_regex.py
# testpath
# testpath-0.3-py3.6.egg-info
# testpath-0.3.1.dist-info
# tests
# theano
# thinc
# thinc-6.5.2.dist-info
# tldextract
# tldextract-2.1.0.dist-info
# tlz
# tools
# toolz
# toolz-0.8.2-py3.6.egg-info
# torch
# torch-0.1.12.post2.dist-info
# torchvision-0.1.8-py3.6.egg
# torchvision.pth
# tornado
# tornado-4.5.1-py3.6.egg-info
# tqdm
# tqdm-4.14.0.dist-info
# traceback2
# traceback2-1.4.0.dist-info
# traitlets
# traitlets-4.3.2-py3.6.egg-info
# traits
# traits-4.6.0.dist-info
# traitsui
# traitsui-5.1.0.dist-info
# traittypes
# traittypes-0.0.6-py3.6.egg-info
# twisted
# twitter
# twitter_api-0.1.5.dist-info
# txaio
# txaio-2.7.1-py3.6.egg-info
# typing-3.6.1.dist-info
# typing.py
# ujson-1.35-py3.6-macosx-10.7-x86_64.egg
# ujson-1.35-py3.6.egg-info
# ujson.cpython-36m-darwin.so
# unicodecsv
# unicodecsv-0.14.1-py3.6.egg-info
# unidecode
# unittest2
# unittest2-1.1.0.dist-info
# update_checker-0.16-py3.6.egg
# uritemplate
# uritemplate-3.0.0.dist-info
# urllib3
# urllib3-1.21.1.dist-info
# utm
# utm-0.4.2.dist-info
# validate.py
# vega
# vega-0.4.4.dist-info
# vpnotebook
# vpnotebook-0.1.3-py3.6.egg-info
# vpnotebook-0.1.3.dist-info
# vpython
# vpython-7.0.2-py3.6.egg-info
# w3lib
# w3lib-1.17.0-py3.6.egg-info
# watchdog
# watchdog-0.8.3.dist-info
# watermark
# watermark-1.3.4.dist-info
# wcwidth
# wcwidth-0.1.7-py3.6.egg-info
# webencodings
# webencodings-0.5.1.dist-info
# werkzeug
# wheel
# wheel-0.29.0-py3.6.egg-info
# widgetsnbextension
# wrapt
# wrapt-1.10.10-py3.6.egg-info
# xgboost-0.6-py3.6.egg
# xlrd
# xlrd-1.0.0-py3.6.egg-info
# xlsxwriter
# xlwings
# xlwings-0.10.4-py3.6.egg-info
# xlwt
# xlwt-1.2.0-py3.6.egg-info
# yahmm
# yahmm-1.1.3-py3.6.egg-info
# yahoo_finance
# yahoo_finance-1.4.0.dist-info
# yaml
# zmq
# zope
# zope.interface-4.4.2-py3.6.egg-info

# %%
from IPython.display import HTML,clear_output, display
import glob, os
import ipywidgets as widgets

files=glob.glob("*ipynb")
def FileBrowse():
    FileSel=widgets.Dropdown(
       options=files,
       value=files[0],
       description='File:',
    ) 
    S  = widgets.Box([widgets.Label(value='  ')],   layout=widgets.Layout(width='8%'))
    button1=widgets.Button(description='Open',disabled=False,
          button_style='',tooltip='Calculate',icon='check')
    button1.style.button_color = '#f27318'
    
    def on_button_clicked(b): 
        FileName=FileSel.value
        display(HTML('<div align="center"><iframe src=%s width="90%%", height=500></iframe></div>' %FileName))
        clear_output(True)
    button1.on_click(on_button_clicked)

    return widgets.VBox(
             [FileSel,
              widgets.HBox([S,button1])
             ])

# %%
FileBrowse()
# Out:
# A Jupyter Widget

# %% [markdown]
# Note
# ---
# Anaconda can be installed on USB stick such as I had created the USB-anaconda as follows:

# %%
from IPython.display import HTML
filename="jupyternb/jupyternb.html"
HTML('<div align="center"><iframe src=%s width=600, height=500></iframe></div>' %filename)
# Out:
# <div align="center"><iframe src=jupyternb/jupyternb.html width=600, height=500></iframe></div>

# %% [markdown]
# Anaconda on Linux
# ---
# To release the power of Hardware on ML, Linux, witout doulbe, is the best OS for us to utilize. To confirm this concept, We tried to  install and test the Anaconda on Live Linux system, <a href="porteus.org">Porteus</a>. Almost without any problem, Python, Jupyter notebook works like as sharm except GPU for tensorflow (caused of the test device, Mac notebook Pro).
#
# <span class="girk">If you have a box with high-end Nvidia GPU, we encourage to build up a high-performance Linux system with GPU-based tenforflow package!</span>
