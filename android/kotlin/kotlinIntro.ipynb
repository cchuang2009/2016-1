# %% [markdown]
# <font style="font-size:2em;color:red">Welcome Android Studio 3.2</font>
# TimeStamp: 2018/09/25<br>
# Google just released new stable Android Studio-3.2 which comes with several new features rewards to try. Open Android Studio and follow the "update: procedure to get the last Android Studio:
# <img src="imgs/3.2/1.png" width=60%>
# <img src="imgs/3.2/2.png" width=40%>
# <img src="imgs/3.2/3.png" width=60%>
# <img src="imgs/3.2/3-1.png" width=40%>
#
# Enjoy!

# %% [markdown]
# Kotlin
# ---
# 1. create a kotlin app,
# - open "activity_main.xml":<br>
#   a). change the layout to LinearLayout and create some UI objects:
#   ```XML
#   <?xml version="1.0" encoding="utf-8"?>
#   <LinearLayout xmlns:android="http://schemas.android.com/apk/res/android"
#     xmlns:app="http://schemas.android.com/apk/res-auto"
#     xmlns:tools="http://schemas.android.com/tools"
#     android:layout_width="match_parent"
#     android:layout_height="match_parent"
#     android:orientation="vertical"
#     tools:context="com.android.kotlinapp1.MainActivity">
#     ...
#    </LinearLayout>
#   ```
#   - create "edittext" UI:
#     ```XML
#     <EditText
#         android:id="@+id/edittext01"
#         android:layout_width="match_parent"
#         android:layout_height="wrap_content" />
#     ```
#   - create "button" UI:
#     ```XML
#     <Button
#         android:id="@+id/button"
#         android:layout_width="match_parent"
#         android:layout_height="wrap_content"
#         android:onClick="onClick"
#         android:text="Submit" />
#     ```
#     Also the editor helper should help user to extract "text"-value to `strings.xml` automatically.
# - open MainActivity.kt and modify the source:
#   In this app, the first Activity includes 3 buttons, provides a∘) `dispaly message`, b∘) `toast inputmessage`, and c∘) `jump to second activity`.
#   - import necessary packages:
#     ```java
#     import android.widget.EditText
#     import android.widget.Toast
#     import android.content.Intent
#     ```
#
#   - acclaim a new "EditEext" object
#     ```java
#     private var edittext:EditText?=null
#     ```
#   - link with UI defined in activity_main.xml:
#     ```java
#     ...
#     setContentView(R.layout.activity_main)
#         edittext=findViewById(R.id.edittext01)
#     ...
#     ```
#   - implement the function, click to display message:
#     ```java
#     fun onClick(view:View){
#         edittext?.setText("Hello world")
#     }
#     ```
#   - toast effect, display the input: create a new button and implement its function:
#   ```java
#   fun onClick_Toast(view: View){
#         Toast.makeText(this, edittext?.text,Toast.LENGTH_LONG).show()
#     }
#   ```
#   - close the app: create a new button object, and link with following function defined in Mainactivity.kt:
#   ```java
#   fun onClick_Close(view: View){
#         finish()
#     }
#   ```

# %% [markdown]
# Indent Jump
# ---
# To change the Activity, we have to implement the indent functionality.
#
# 1. Acclaim the new indent, MainActivitytwo, in **AndroidManifest.xml**:
# ```XML
# <activity android:name=".MainActivity">
#             ...
# </activity>
# <activity android:name=".MainActivitytwo" android:label="SecondActivity"></activity>
# ```
# where MainActivitytwo(<font color="brown">.kt</font>) is the second activity file created in the following step.
# 2. Create UI file, activity_main2.xml, and create new button object:
# ```XML
# <?xml version="1.0" encoding="utf-8"?>
# <LinearLayout xmlns:android="http://schemas.android.com/apk/res/android"
#     ...
#     tools:context="com.android.kotlinapp1.MainActivitytwo">
# <Button
#         android:id="@+id/button4"
#         android:layout_width="match_parent"
#         android:layout_height="wrap_content"
#         android:onClick="onClick_Close"
#         android:text="Close"
# />
# ```
# 3. Create a new source code, MainActivitytwo.kt:
# ```java
# ...
# class MainActivitytwo : AppCompatActivity() {
#
#     override fun onCreate(savedInstanceState: Bundle?) {
#         super.onCreate(savedInstanceState)
#         setContentView(R.layout.activity_main2)
#     }
#     fun onClick_Close(view: View){
#         finish()
#     }
# }
# ```
# 4. To implement the function of jumping from MainActivity to MainActivitytwo, add a new button in activity_main.xml, and create a new function as follows:
# ```java
# import android.content.Intent
#     ...
#     fun onClick_showSecond(view: View){
#         var intent = Intent(this,MainActivitytwo::class.java)
#         startActivity(intent)
#     }
# ```

# %% [markdown]
# How WebView integrated
# ---
# Internet is the one of the best features availed by mobile devices. Not only capable of browsing the web-site contents, but providing the HTML resources by the help of Android UI widget, `webview` and related.
#
# **OUTLINE**<br>
# <pre style="font-family:chalkboard;font-size:1.2em;color:brown;">
# AndroidManifest.xml
#   acclaim new Activity: WebViewActivity
#      ⬇︎
# main_activity.xml
#   WebView: webview01
#      ⬇︎
# MainActivity.kt
#      ⬇︎
#   webview!!.loadUrl(...)
# </pre>
# **Details**<br>
# 1. **acclaim new activity**, <font color="brown">WebViewActivity</font>, in AndroidManifest.xml; and enable <font color="brown">internet</font> permission:
# ```XML
# <manifest xmlns:android="http://schemas.android.com/apk/res/android"
#     package="com.android.kotlinapp1">
#     <uses-permission android:name="android.permission.INTERNET" />
#     ...
#     <activity android:name=".MainActivity">
#      ...
#     </activity>
#     <activity android:name=".WebViewActivity" android:label="WebViewActivity"></activity>
#     ...
# ```
# - create <font color="brown">webview.xml</font> in `res/layout`, which contains a webview widget, called `webview01`:
# ```XML
# <?xml version="1.0" encoding="utf-8"?>
# <LinearLayout xmlns:android="http://schemas.android.com/apk/res/android"
#     xmlns:app="http://schemas.android.com/apk/res-auto"
#     xmlns:tools="http://schemas.android.com/tools"
#     android:layout_width="match_parent"
#     android:layout_height="match_parent"
#     android:orientation="vertical"
#     tools:context="com.android.kotlinapp1.WebViewActivity"
#     >
#
#     <WebView
#         android:id="@+id/webview01"
#         android:layout_width="fill_parent"
#         android:layout_height="fill_parent" />
# </LinearLayout>
# ```
# - create a new button, <font color="brown">button04</font> in `main_activity2.xml`, with `onClick` function, waiting for service:
# ```XML
#     <Button
#         android:id="@+id/button05"
#         android:layout_width="match_parent"
#         android:layout_height="wrap_content"
#         android:onClick="onClick5"
#         android:text="Google Search" />
# ```
# implement the `onClick` function with `Intent`, waiting for loading WebViewActivity, introduced later:
# ```java
# ...
# class MainActivitytwo : AppCompatActivity() {
#     ...
#     fun onClick5(view: View){
#         var intent = Intent(this,WebViewActivity::class.java)
#         startActivity(intent)
#     }
# }
# ```
# - create a new folder, <font color="blue">assets</font>, in <font color="blue">&#36;Project/app/src/main</font>, at which contains at least one HTML file, for instance <font color="brown">index.html</font>;
# ```
# ▼ 🗂 app
#    ▶︎ 🗂 manifests
#    ▶︎ 🗂 java
#    ▼ 📂 assets
#       📠 index.html
#    ▶︎ 🗂 res
# ```
# - create a new <font color="blue">WebViewActivity.kt</font> by "right click" mouse, [New]➜[Activity]➜[Basic Activity] with WebviewActivity (Activity Name), and webview (UI Name):
#
# a). acclaim the activity in AndroidManifest.xml;<br>
# b). webview.xml: inplace the layout with "Linearlayout", and add one "webview" UI.<br>
# c). the codes, in WebViewActivity", is as follows:
#
# ```java
# ...
# import android.os.Bundle
# import android.support.v7.app.AppCompatActivity
# import android.webkit.WebView
#
# class WebViewActivity: AppCompatActivity() {
#
#     private var webview: WebView? = null
#
#     override fun onCreate(savedInstanceState: Bundle?) {
#         super.onCreate(savedInstanceState)
#         setContentView(R.layout.webview)
#
#         webview = findViewById<WebView>(R.id.webview01)
#         // !! allow null webview objecb
#         webview!!.getSettings().setJavaScriptEnabled(true);
#         // load website
#         // webview!!.loadUrl("http://www.cgu.edu.tw")
#         webview!!.loadUrl("file:///android_asset/index.html")
#     }
#
# }
# ```

# %% [markdown]
# HTML Code
# ---
# <img src="imgs/3.2/4.png" width=90% />
